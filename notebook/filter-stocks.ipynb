# %%
import os
try:
    print(file_path)
except:
    file_path = os.path.abspath('')
    os.chdir(os.path.dirname(file_path))
    print(file_path)
# Out:
# /root/code_Bao/Vietnamese_stocks_forecasting/notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
pd.set_option('display.max_columns', None)
import stumpy
import matplotlib.pyplot as plt
from datetime import datetime,timedelta
import numpy.testing as npt
import matplotlib.pyplot as plt
from matplotlib.patches import Rectangle

import os
from vnstock import * #import all functions, including functions that provide OHLC data for charting
# from vnstock.chart import * # import chart functions

# %%
# df = stock_historical_data("HAH", "2020-01-01", "2023-10-10", "1D", "stock")
# fig = candlestick_chart(df, ma_periods=[50,200], show_volume=False, reference_period=300, figure_size=(15, 8), 
#                         title='VIC - Candlestick Chart with MA and Volume', x_label='Date', y_label='Price', 
#                         colors=('lightgray', 'gray'), reference_colors=('black', 'blue'))
# fig.show()

# %% [markdown]
# Sử dụng các tiêu chí lọc như sau để thiết lập tham số params.
#
# - CANSLIM: epsGrowth1Year, lastQuarterProfitGrowth, roe, avgTradingValue20Day, relativeStrength1Month
# - Giá trị: roe, pe, avgTradingValue20Day
# - Cổ tức cao: dividendYield, avgTradingValue20Day
# - Phá nền mua: avgTradingValue20Day, forecastVolumeRatio, breakout: 'BULLISH'
# - Giá tăng + Đột biến khối lượng: avgTradingValue20Day, forecastVolumeRatio
# - Vượt đỉnh 52 tuần: avgTradingValue20Day, priceBreakOut52Week: 'BREAK_OUT'
# - Phá đáy 52 tuần: avgTradingValue20Day, priceWashOut52Week: 'WASH_OUT'
# - Uptrend ngắn hạn: avgTradingValue20Day, uptrend: 'buy-signal'
# - Vượt trội ngắn hạn: relativeStrength3Day,
# - Tăng trưởng: epsGrowth1Year, roe, avgTradingValue20Day

# %%
def filter_stocks(param):
    df = stock_screening_insights (param, size=1700, drop_lang='vi')
    if len(df)!= 0:
        print(df.ticker.unique())
    return df

# %% [markdown]
# ## canslim

# %%
canslim_params = {
    "exchangeName": "HOSE",
    "marketCap": (1_000, 200_000),
    "epsGrowth1Year": (25, 100),  # Minimum 1-year EPS growth
    "lastQuarterProfitGrowth": (25, 100),  # Minimum last quarter profit growth
    "roe": (20, 100),  # Minimum Return on Equity (ROE)
    "avgTradingValue20Day": (50, 1000),  # Minimum 20-day average trading value
}
df = filter_stocks(canslim_params)
df.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
params = {
            "exchangeName": "HOSE",
            "marketCap": (1_000, 200_000),
            'uptrend': 'buy-signal',
            'tcbsBuySellSignal':'BUY',
            "avgTradingValue20Day": (10, 100_000),
            'priceNearRealtime': (15,80),
        }
df = stock_screening_insights (params, size=1700, drop_lang='vi')
df.head()
# Out:
#   ticker companyName  marketCap   roe  stockRating  businessOperation  \
# 0    ACB                  85643  24.3          4.2                4.6
# 1    GMD                  19883  29.5          3.8                3.0
# 2    HPG                 145951   1.9          3.9                2.6
# 3    NKG                   5068  -4.6          3.4                1.9
#
#    businessModel  financialHealth  alpha  beta  activeBuyPercentage  \
# 0            3.9              3.6    0.2   1.1                 56.4
# 1            4.3              4.6    0.0   0.6                 55.3
# 2            4.4              2.8    0.7   1.8                 56.2
# 3            3.2              2.2    0.2   1.9                 48.6
#
#    strongBuyPercentage  suddenlyHighVolumeMatching  forecastVolumeRatio    pe  \
# 0                 41.0                       108.6                  1.2   5.7
# 1                 99.8                       211.1                  2.7   8.7
# 2                 93.9                        15.1                  1.1  78.0
# 3                 43.3                        11.9                  1.4 -19.8
#
#     pb  evEbitda  dividendYield  revenueGrowth1Year  revenueGrowth5Year  \
# 0  1.3       NaN            5.5               22.18               20.27
# 1  2.4      13.5            4.5               21.58               -0.43
# 2  1.5      18.0            0.0               -5.53               25.09
# 3  0.9      27.1            0.0              -18.11               12.83
#
#    epsGrowth1Year  epsGrowth5Year  grossMargin  netMargin  doe  \
# 0           42.54           35.07          NaN      47.93  NaN
# 1           62.36           14.03        46.57      25.47  0.2
# 2          -75.39           -4.01        12.62       7.04  0.6
# 3             NaN             NaN         4.81       0.56  0.8
#
#    avgTradingValue5Day  avgTradingValue10Day  avgTradingValue20Day  \
# 0                96.65                 98.50                102.60
# 1                64.97                 67.87                 86.55
# 2               496.87                436.49                442.51
# 3               147.55                128.53                137.15
#
#    relativeStrength3Day  relativeStrength1Month  relativeStrength3Month  \
# 0                    48                      81                      60
# 1                    86                      74                      95
# 2                    81                      58                      48
# 3                    86                      61                      74
#
#    relativeStrength1Year  totalTradingValue  priceNearRealtime  rsi14  \
# 0                     63             108.31              22.05   51.4
# 1                     82             140.07              65.00   56.1
# 2                     91             514.95              25.10   52.4
# 3                     81             187.78              19.25   52.5
#
#    foreignVolumePercent  tcRS  foreignBuySell20Session  \
# 0                 30.00    63                        0
# 1                 48.34    84                     1673
# 2                 24.99    70                     2790
# 3                  9.72    76                     -189
#
#    numIncreaseContinuousDay  numDecreaseContinuousDay   eps  volumeVsVSma5  \
# 0                       NaN                       1.0  3839            1.4
# 1                       3.0                       NaN  7504            3.6
# 2                       NaN                       1.0   322            1.2
# 3                       3.0                       NaN  -975            1.6
#
#    volumeVsVSma10  volumeVsVSma20  volumeVsVSma50  priceGrowth1Week  \
# 0             1.2             1.0             0.9              2.32
# 1             2.5             1.7             1.4              4.00
# 2             1.3             1.2             0.9              7.49
# 3             1.6             1.4             1.1              6.94
#
#    priceGrowth1Month  prev1DayGrowthPercent  prev1MonthGrowthPercent  \
# 0               1.15                  -1.12                     1.15
# 1               0.00                   2.36                     0.00
# 2               0.60                  -0.59                     0.60
# 3               0.52                   0.79                     0.52
#
#    prev1YearGrowthPercent  prev5YearGrowthPercent  freeTransferRate  \
# 0                   23.64                   92.82                85
# 1                   41.71                  167.40                90
# 2                   65.13                   79.22                55
# 3                   49.22                  221.61                75
#
#    netCashPerMarketCap  netCashPerTotalAssets  profitForTheLast4Quarters  \
# 0                  NaN                    NaN                    14909.0
# 1                 -4.4                   -6.6                     2295.5
# 2                -33.1                  -27.8                     1870.7
# 3                -74.1                  -30.9                     -256.6
#
#    lastQuarterRevenueGrowth  secondQuarterRevenueGrowth  \
# 0                      18.8                        15.9
# 1                       0.6                        -6.7
# 2                     -16.5                       -21.2
# 3                      -3.7                       -23.6
#
#    lastQuarterProfitGrowth  secondQuarterProfitGrowth  percent1YearFromPeak  \
# 0                     12.6                       -2.0                  -9.6
# 1                      4.2                      471.7                  -4.4
# 2                      NaN                      -63.8                 -14.6
# 3                      NaN                      -37.8                 -18.6
#
#    percentAwayFromHistoricalPeak  percent1YearFromBottom  \
# 0                          -27.4                    47.5
# 1                           -2.0                    84.2
# 2                          -42.8                   112.7
# 3                          -57.2                   179.4
#
#    percentOffHistoricalBottom exchangeName.en              industryName.en  \
# 0                       671.5            HOSE                        Banks
# 1                      1535.9            HOSE  Industrial Goods & Services
# 2                      3235.6            HOSE              Basic Resources
# 3                      1114.3            HOSE              Basic Resources
#
#    uptrend.en            priceVsSMA20.en foreignTransaction.en  \
# 0  Buy Signal  Price cross below SMA(20)            Buy > Sell
# 1  Buy Signal        Price above SMA(20)            Buy > Sell
# 2  Buy Signal        Price above SMA(20)            Buy > Sell
# 3  Buy Signal        Price above SMA(20)            Buy < Sell
#
#   tcbsBuySellSignal.en                 macdHistogram.en  \
# 0                  Buy  MACD Histogram > 0 and increase
# 1                  Buy  MACD Histogram < 0 and increase
# 2                  Buy  MACD Histogram > 0 and increase
# 3                  Buy  MACD Histogram > 0 and increase
#
#              priceVsSma50.en sarVsMacdHist.en bollingBandSignal.en  \
# 0  Price cross below SMA(50)       Buy signal          Sell signal
# 1        Price above SMA(50)              NaN                  NaN
# 2        Price below SMA(50)              NaN                  NaN
# 3        Price below SMA(50)              NaN                  NaN
#
#   rsi14Status.en hasFinancialReport.en      priceVsSMA100.en tcbsRecommend.en
# 0        Neutral                   Yes  Price below SMA(100)              NaN
# 1        Neutral                   Yes  Price above SMA(100)      Wait to buy
# 2        Neutral                   Yes  Price below SMA(100)      Wait to buy
# 3        Neutral                   Yes  Price below SMA(100)              NaN

# %% [markdown]
# ## Payback time

# %%
# https://www.youtube.com/watch?v=4YPyxfXML0A&t=1825s
paybacktime_params = {
    "exchangeName": "HOSE",
    "marketCap": (1_000, 200_000),
    'revenueGrowth5Year': (15,100),
    'pe':(10,20),
    "epsGrowth5Year": (10, 100),  # Minimum 1-year EPS growth
    "roe": (15, 100),  # Minimum Return on Equity (ROE)
    
    'priceNearRealtime': (15,80),
#     "lastQuarterProfitGrowth": (2, 100),  # Minimum last quarter profit growth
    "avgTradingValue20Day": (10, 2000),  # Minimum 20-day average trading value
#     "breakout": 'BULLISH',  # Only buy stocks when the market is in an uptrend
}
df = filter_stocks(paybacktime_params)
df.head()
# Out:
# ['CTR' 'DGW' 'DHC' 'PNJ']
#   ticker companyName  marketCap   roe  stockRating  businessOperation  \
# 0    CTR                   8865  29.9          3.9                3.9
# 1    DGW                   7819  17.3          3.9                3.9
# 2    DHC                   3344  17.3          4.3                3.8
# 3    PNJ                  24206  20.3          4.0                4.1
#
#    businessModel  financialHealth  alpha  beta  activeBuyPercentage  \
# 0            3.9              4.0    0.0   1.5                 76.6
# 1            3.5              4.0   -1.0   2.0                 51.8
# 2            2.8              4.4   -0.7   0.6                 80.4
# 3            4.0              4.4    0.3   0.7                 39.9
#
#    strongBuyPercentage  suddenlyHighVolumeMatching  forecastVolumeRatio    pe  \
# 0                  5.7                        27.8                  1.8  17.8
# 1                 95.1                         6.9                  0.9  18.6
# 2                 84.0                       443.3                  4.6  10.6
# 3                 91.6                       924.0                  5.1  13.4
#
#     pb  evEbitda  dividendYield  revenueGrowth1Year  revenueGrowth5Year  \
# 0  4.9      11.4            2.0               25.82               23.19
# 1  3.0      14.5            2.7                5.28               41.96
# 2  1.8      10.3            9.5               -5.51               37.18
# 3  2.6      10.5            2.3               73.31               25.28
#
#    epsGrowth1Year  epsGrowth5Year  grossMargin  netMargin  doe  \
# 0           18.03           25.01         7.54       4.56  0.8
# 1            4.49           35.51         7.11       1.89  0.8
# 2          -21.17           32.68        13.46       7.04  0.3
# 3           75.96           11.61        17.31       3.66  0.2
#
#    avgTradingValue5Day  avgTradingValue10Day  avgTradingValue20Day  \
# 0                13.85                 15.53                 18.51
# 1                86.83                 81.95                 98.22
# 2                13.32                 11.67                 16.10
# 3                45.65                 39.89                 33.88
#
#    relativeStrength3Day  relativeStrength1Month  relativeStrength3Month  \
# 0                    80                      68                      87
# 1                    91                      10                      38
# 2                    80                      38                      80
# 3                    44                      52                      49
#
#    relativeStrength1Year  totalTradingValue  priceNearRealtime  rsi14  \
# 0                     82              21.74              77.50   53.1
# 1                     14              82.44              46.80   38.8
# 2                     39              36.95              41.55   47.6
# 3                     31             129.15              73.80   38.9
#
#    foreignVolumePercent  tcRS  foreignBuySell20Session  \
# 0                 10.12    79                       93
# 1                 23.34    38                     2637
# 2                 34.36    59                      926
# 3                 49.00    44                      -30
#
#    numIncreaseContinuousDay  numDecreaseContinuousDay   eps  volumeVsVSma5  \
# 0                         3                       NaN  4346            2.2
# 1                         0                       0.0  2517            1.1
# 2                         3                       NaN  3929            5.9
# 3                         0                       0.0  5506            6.4
#
#    volumeVsVSma10  volumeVsVSma20  volumeVsVSma50  priceGrowth1Week  \
# 0             1.6             1.2             0.7              3.33
# 1             1.1             1.0             0.8             -3.60
# 2             4.6             2.6             2.4              4.79
# 3             4.7             4.5             3.6              0.27
#
#    priceGrowth1Month  prev1DayGrowthPercent  prev1MonthGrowthPercent  \
# 0              -1.27                   3.06                    -1.27
# 1             -17.96                   0.00                   -17.96
# 2              -6.00                   5.73                    -6.00
# 3              -4.38                   0.00                    -4.38
#
#    prev1YearGrowthPercent  prev5YearGrowthPercent  freeTransferRate  \
# 0                   50.26                  770.62                35
# 1                  -19.48                  637.91                55
# 2                    3.77                  127.11                70
# 3                   -1.03                    7.86                85
#
#    netCashPerMarketCap  netCashPerTotalAssets  profitForTheLast4Quarters  \
# 0                -11.0                  -14.2                      497.2
# 1                 -6.0                   -6.7                      420.6
# 2                -12.5                  -14.6                      316.3
# 3                 -5.1                   -9.4                     1805.9
#
#    lastQuarterRevenueGrowth  secondQuarterRevenueGrowth  \
# 0                      18.3                        21.5
# 1                     -10.8                        -6.4
# 2                     -18.1                       -19.4
# 3                      -6.1                       -17.4
#
#    lastQuarterProfitGrowth  secondQuarterProfitGrowth  percent1YearFromPeak  \
# 0                      9.6                       20.6                  -9.5
# 1                    -43.2                      -39.4                 -25.5
# 2                    -13.3                      -19.0                 -15.1
# 3                      0.4                       -8.0                 -20.9
#
#    percentAwayFromHistoricalPeak  percent1YearFromBottom  \
# 0                          -18.4                   123.9
# 1                          -45.3                    73.0
# 2                          -55.2                    76.4
# 3                          -30.5                    12.2
#
#    percentOffHistoricalBottom exchangeName.en             industryName.en  \
# 0                       878.9            HOSE    Construction & Materials
# 1                      1597.1            HOSE                      Retail
# 2                      3030.9            HOSE             Basic Resources
# 3                      1631.8            HOSE  Personal & Household Goods
#
#              priceVsSMA20.en foreignTransaction.en tcbsRecommend.en  \
# 0  Price cross above SMA(20)            Buy > Sell      Wait to buy
# 1        Price below SMA(20)            Buy > Sell              NaN
# 2        Price below SMA(20)            Buy > Sell              NaN
# 3        Price below SMA(20)            Buy > Sell              NaN
#
#   tcbsBuySellSignal.en                 macdHistogram.en      priceVsSma50.en  \
# 0           Strong buy  MACD Histogram > 0 and increase  Price below SMA(50)
# 1                 Sell  MACD Histogram < 0 and increase  Price below SMA(50)
# 2              Neutral  MACD Histogram < 0 and increase  Price below SMA(50)
# 3                 Sell  MACD Histogram < 0 and increase  Price below SMA(50)
#
#   sarVsMacdHist.en bollingBandSignal.en rsi14Status.en hasFinancialReport.en  \
# 0       Buy signal           Buy signal        Neutral                   Yes
# 1              NaN                  NaN        Neutral                   Yes
# 2              NaN                  NaN        Neutral                   Yes
# 3              NaN                  NaN        Neutral                   Yes
#
#        priceVsSMA100.en            priceVsSma10.en
# 0  Price below SMA(100)                        NaN
# 1  Price below SMA(100)                        NaN
# 2  Price below SMA(100)  Price cross above SMA(10)
# 3  Price below SMA(100)                        NaN

# %% [markdown]
# ## Tang Truong

# %%
tangtruong_params = {
    "exchangeName": "HOSE",
    "marketCap": (1_000, 200_000),
    "epsGrowth1Year": (10, 100),  # Minimum 1-year EPS growth
    "roe": (15, 100),  # Minimum Return on Equity (ROE)
    'priceNearRealtime': (15,80),
    "avgTradingValue20Day": (10, 2000),  # Minimum 20-day average trading value
}
df = filter_stocks(tangtruong_params)
df.head()
# Out:
# ['ACB' 'CTG' 'CTR' 'GAS' 'GMD' 'HAH' 'HDB' 'MBB' 'PHR' 'PNJ' 'REE' 'SAB'
#  'STB' 'TPB' 'VGC' 'VHC' 'VIB' 'VPI']
#   ticker companyName  marketCap   roe  stockRating  businessOperation  \
# 0    ACB                  85643  24.3          4.2                4.6
# 1    CTG                 134561  16.0          4.0                3.1
# 2    CTR                   8865  29.9          3.9                3.9
# 3    GAS                 181672  20.5          4.1                3.1
# 4    GMD                  19883  29.5          3.8                3.0
#
#    businessModel  financialHealth  alpha  beta  activeBuyPercentage  \
# 0            3.9              3.6    0.2   1.1                 56.4
# 1            3.8              3.4    0.4   1.2                 38.9
# 2            3.9              4.0    0.0   1.5                 76.6
# 3            4.5              5.0   -0.2   0.8                 31.5
# 4            4.3              4.6    0.0   0.6                 55.3
#
#    strongBuyPercentage  suddenlyHighVolumeMatching  forecastVolumeRatio    pe  \
# 0                 41.0                       108.6                  1.2   5.7
# 1                 92.8                       149.8                  1.4   7.4
# 2                  5.7                        27.8                  1.8  17.8
# 3                 70.9                        13.8                  1.3  15.0
# 4                 99.8                       211.1                  2.7   8.7
#
#     pb  evEbitda  dividendYield  revenueGrowth1Year  revenueGrowth5Year  \
# 0  1.3       NaN            5.5               22.18               20.27
# 1  1.1       NaN            0.0               20.62               14.47
# 2  4.9      11.4            2.0               25.82               23.19
# 3  3.0      10.6            4.4               27.51                9.32
# 4  2.4      13.5            4.5               21.58               -0.43
#
#    epsGrowth1Year  epsGrowth5Year  grossMargin  netMargin  doe  \
# 0           42.54           35.07          NaN      47.93  NaN
# 1           19.07           17.68          NaN      22.40  NaN
# 2           18.03           25.01         7.54       4.56  0.8
# 3           70.63            4.95        16.64      10.74  0.1
# 4           62.36           14.03        46.57      25.47  0.2
#
#    avgTradingValue5Day  avgTradingValue10Day  avgTradingValue20Day  \
# 0                96.65                 98.50                102.60
# 1                75.52                 79.57                 75.40
# 2                13.85                 15.53                 18.51
# 3                28.10                 34.46                 45.90
# 4                64.97                 67.87                 86.55
#
#    relativeStrength3Day  relativeStrength1Month  relativeStrength3Month  \
# 0                    48                      81                      60
# 1                    33                      46                      45
# 2                    80                      68                      87
# 3                    49                      27                      66
# 4                    86                      74                      95
#
#    relativeStrength1Year  totalTradingValue  priceNearRealtime  rsi14  \
# 0                     63             108.31              22.05   51.4
# 1                     58             100.16              28.00   40.3
# 2                     82              21.74              77.50   53.1
# 3                     20              35.90              79.10   41.7
# 4                     82             140.07              65.00   56.1
#
#    foreignVolumePercent  tcRS  foreignBuySell20Session  \
# 0                 30.00    63                        0
# 1                 27.17    46                    -2232
# 2                 10.12    79                       93
# 3                  2.89    40                    -1665
# 4                 48.34    84                     1673
#
#    numIncreaseContinuousDay  numDecreaseContinuousDay   eps  volumeVsVSma5  \
# 0                       NaN                       1.0  3839            1.4
# 1                       NaN                       1.0  3773            1.8
# 2                       3.0                       NaN  4346            2.2
# 3                       NaN                       1.0  5283            1.7
# 4                       3.0                       NaN  7504            3.6
#
#    volumeVsVSma10  volumeVsVSma20  volumeVsVSma50  priceGrowth1Week  \
# 0             1.2             1.0             0.9              2.32
# 1             1.4             1.5             0.8             -0.71
# 2             1.6             1.2             0.7              3.33
# 3             1.2             0.8             0.8              1.93
# 4             2.5             1.7             1.4              4.00
#
#    priceGrowth1Month  prev1DayGrowthPercent  prev1MonthGrowthPercent  \
# 0               1.15                  -1.12                     1.15
# 1              -2.44                  -0.88                    -2.44
# 2              -1.27                   3.06                    -1.27
# 3              -6.06                  -0.13                    -6.06
# 4               0.00                   2.36                     0.00
#
#    prev1YearGrowthPercent  prev5YearGrowthPercent  freeTransferRate  \
# 0                   23.64                   92.82                85
# 1                   18.64                   59.80                15
# 2                   50.26                  770.62                35
# 3                  -11.71                  -10.32                 5
# 4                   41.71                  167.40                90
#
#    netCashPerMarketCap  netCashPerTotalAssets  profitForTheLast4Quarters  \
# 0                  NaN                    NaN                    14909.0
# 1                  NaN                    NaN                    18133.2
# 2                -11.0                  -14.2                      497.2
# 3                  2.6                    5.5                    12133.1
# 4                 -4.4                   -6.6                     2295.5
#
#    lastQuarterRevenueGrowth  secondQuarterRevenueGrowth  \
# 0                      18.8                        15.9
# 1                       0.4                        11.5
# 2                      18.3                        21.5
# 3                      -9.1                       -13.1
# 4                       0.6                        -6.7
#
#    lastQuarterProfitGrowth  secondQuarterProfitGrowth  percent1YearFromPeak  \
# 0                     12.6                       -2.0                  -9.6
# 1                     15.7                       12.0                 -16.8
# 2                      9.6                       20.6                  -9.5
# 3                    -21.5                      -38.0                 -18.0
# 4                      4.2                      471.7                  -4.4
#
#    percentAwayFromHistoricalPeak  percent1YearFromBottom  \
# 0                          -27.4                    47.5
# 1                          -31.9                    27.3
# 2                          -18.4                   123.9
# 3                          -35.0                     7.4
# 4                           -2.0                    84.2
#
#    percentOffHistoricalBottom exchangeName.en              industryName.en  \
# 0                       671.5            HOSE                        Banks
# 1                       362.6            HOSE                        Banks
# 2                       878.9            HOSE     Construction & Materials
# 3                       276.8            HOSE                    Utilities
# 4                      1535.9            HOSE  Industrial Goods & Services
#
#    uptrend.en            priceVsSMA20.en foreignTransaction.en  \
# 0  Buy Signal  Price cross below SMA(20)            Buy > Sell
# 1         NaN        Price below SMA(20)            Buy < Sell
# 2         NaN  Price cross above SMA(20)            Buy > Sell
# 3         NaN        Price below SMA(20)            Buy < Sell
# 4  Buy Signal        Price above SMA(20)            Buy > Sell
#
#   tcbsBuySellSignal.en                 macdHistogram.en  \
# 0                  Buy  MACD Histogram > 0 and increase
# 1                 Sell  MACD Histogram < 0 and increase
# 2           Strong buy  MACD Histogram > 0 and increase
# 3                 Sell  MACD Histogram < 0 and increase
# 4                  Buy  MACD Histogram < 0 and increase
#
#              priceVsSma50.en sarVsMacdHist.en bollingBandSignal.en  \
# 0  Price cross below SMA(50)       Buy signal          Sell signal
# 1        Price below SMA(50)              NaN                  NaN
# 2        Price below SMA(50)       Buy signal           Buy signal
# 3        Price below SMA(50)              NaN                  NaN
# 4        Price above SMA(50)              NaN                  NaN
#
#   rsi14Status.en hasFinancialReport.en      priceVsSMA100.en tcbsRecommend.en  \
# 0        Neutral                   Yes  Price below SMA(100)              NaN
# 1        Neutral                   Yes  Price below SMA(100)              NaN
# 2        Neutral                   Yes  Price below SMA(100)      Wait to buy
# 3        Neutral                   Yes  Price below SMA(100)      Wait to buy
# 4        Neutral                   Yes  Price above SMA(100)      Wait to buy
#
#   priceBreakOut52Week.en breakout.en priceVsSma10.en priceVsSMA5.en
# 0                    NaN         NaN             NaN            NaN
# 1                    NaN         NaN             NaN            NaN
# 2                    NaN         NaN             NaN            NaN
# 3                    NaN         NaN             NaN            NaN
# 4                    NaN         NaN             NaN            NaN

# %% [markdown]
# ## my params

# %%
my_params = {
    "exchangeName": "HOSE,HNX",
    "marketCap": (1_000, 200_000),
    "roe": (10, 100),  # Minimum Return on Equity (ROE)
    'pe': (10,20),
    'priceNearRealtime': (10,100),
    "avgTradingValue20Day": (100, 1000),  # Minimum 20-day average trading value
#     'uptrend': 'buy-signal',
    'macdHistogram': 'macdHistLT0Increase',
    'strongBuyPercentage': (20,100),
    'relativeStrength3Day': (50,100),
}
df = filter_stocks(my_params)
df.head()
# Out:
# ['FPT' 'IDC' 'MBS' 'VRE']
#   ticker companyName  marketCap   roe  stockRating  businessOperation  \
# 0    FPT                 110487  28.0          3.6                3.3
# 1    IDC                  14817  22.0          4.2                3.8
# 2    MBS                   8053  11.1          3.7                4.5
# 3    VRE                  55445  11.9          3.8                2.8
#
#    businessModel  financialHealth  alpha  beta  activeBuyPercentage  \
# 0            4.0              4.2    0.1   0.8                 36.6
# 1            4.0              4.4   -0.6   2.1                 37.7
# 2            3.2              2.6    0.1   2.7                 42.3
# 3            4.2              5.0    0.1   1.3                 67.7
#
#    strongBuyPercentage  suddenlyHighVolumeMatching  forecastVolumeRatio    pe  \
# 0                 90.8                       341.8                  2.1  18.1
# 1                 35.9                         0.0                  0.6  14.1
# 2                 37.5                         0.0                  0.8  16.7
# 3                 34.3                       158.8                  1.7  13.4
#
#     pb  evEbitda  dividendYield  revenueGrowth1Year  revenueGrowth5Year  \
# 0  4.7      12.5            3.1               23.42                0.63
# 1  3.4       6.3            0.0               74.03                8.75
# 2  1.7      15.4            0.0              -11.70               18.51
# 3  1.5       8.6            0.0               24.96                5.93
#
#    epsGrowth1Year  epsGrowth5Year  grossMargin  netMargin  doe  \
# 0           22.43            5.30        39.94      12.64  0.7
# 1          289.05           36.84        28.07      11.15  0.6
# 2          -12.37           67.34        67.88      30.85  1.5
# 3          111.19            6.49        51.01      39.51  0.1
#
#    avgTradingValue5Day  avgTradingValue10Day  avgTradingValue20Day  \
# 0               244.05                241.39                257.71
# 1               156.06                191.54                211.12
# 2                75.02                 76.57                100.51
# 3               166.53                155.08                100.27
#
#    relativeStrength3Day  relativeStrength1Month  relativeStrength3Month  \
# 0                    60                      45                      85
# 1                    65                      59                      64
# 2                    98                      13                      78
# 3                    86                      36                      29
#
#    relativeStrength1Year  totalTradingValue  priceNearRealtime  rsi14  \
# 0                     78             423.05               87.0   41.6
# 1                     52             102.38               44.9   44.1
# 2                     87              64.24               18.4   43.4
# 3                     25             301.78               24.4   42.9
#
#    foreignVolumePercent  tcRS  foreignBuySell20Session  \
# 0                 49.00    67                     -154
# 1                 15.03    60                     8248
# 2                  0.58    69                      -89
# 3                 32.45    44                    -8216
#
#    numIncreaseContinuousDay  numDecreaseContinuousDay   eps  volumeVsVSma5  \
# 0                       NaN                       1.0  4798            2.6
# 1                       NaN                       1.0  3177            0.7
# 2                       NaN                       1.0  1105            1.0
# 3                       3.0                       NaN  1818            2.7
#
#    volumeVsVSma10  volumeVsVSma20  volumeVsVSma50  priceGrowth1Week  \
# 0             2.1             1.7             1.8              0.00
# 1             0.6             0.5             0.6             -4.67
# 2             0.9             0.7             0.7             -0.54
# 3             2.4             3.4             3.1              6.55
#
#    priceGrowth1Month  prev1DayGrowthPercent  prev1MonthGrowthPercent  \
# 0              -6.15                  -2.25                    -6.15
# 1              -4.47                  -1.10                    -4.47
# 2             -16.36                  -1.08                   -16.36
# 3             -11.11                   4.95                   -11.11
#
#    prev1YearGrowthPercent  prev5YearGrowthPercent  freeTransferRate  \
# 0                   38.19                  302.61                85
# 1                   13.76                  190.64                65
# 2                   60.30                  158.88                25
# 3                   -6.15                  -18.17                40
#
#    netCashPerMarketCap  netCashPerTotalAssets  profitForTheLast4Quarters  \
# 0                -10.8                  -19.2                     6093.7
# 1                -13.9                  -12.2                     1048.5
# 2                -89.8                  -58.3                      483.6
# 3                  8.3                   10.3                     4132.1
#
#    lastQuarterRevenueGrowth  secondQuarterRevenueGrowth  \
# 0                      23.4                        23.7
# 1                     -29.7                       -27.2
# 2                      25.4                       -21.8
# 3                      66.2                        17.5
#
#    lastQuarterProfitGrowth  secondQuarterProfitGrowth  percent1YearFromPeak  \
# 0                     19.6                       20.7                 -13.7
# 1                    -61.9                      -62.6                 -15.6
# 2                     37.2                        2.6                 -26.4
# 3                     66.0                       29.4                 -23.8
#
#    percentAwayFromHistoricalPeak  percent1YearFromBottom  \
# 0                          -12.1                    67.0
# 1                          -45.7                   108.7
# 2                          -40.3                   161.2
# 3                          -49.5                    13.0
#
#    percentOffHistoricalBottom exchangeName.en     industryName.en  \
# 0                      2908.8            HOSE          Technology
# 1                       253.6             HNX         Real Estate
# 2                       776.7             HNX  Financial Services
# 3                        37.9            HOSE         Real Estate
#
#        priceVsSMA20.en foreignTransaction.en tcbsRecommend.en  \
# 0  Price below SMA(20)            Buy < Sell      Wait to buy
# 1  Price below SMA(20)            Buy > Sell              NaN
# 2  Price below SMA(20)            Buy < Sell              NaN
# 3  Price below SMA(20)            Buy > Sell              NaN
#
#   tcbsBuySellSignal.en                 macdHistogram.en  \
# 0              Neutral  MACD Histogram < 0 and increase
# 1                 Sell  MACD Histogram < 0 and increase
# 2                 Sell  MACD Histogram < 0 and increase
# 3                 Sell  MACD Histogram < 0 and increase
#
#              priceVsSma10.en      priceVsSma50.en rsi14Status.en  \
# 0  Price cross below SMA(10)  Price below SMA(50)        Neutral
# 1                        NaN  Price below SMA(50)        Neutral
# 2                        NaN  Price below SMA(50)        Neutral
# 3  Price cross above SMA(10)  Price below SMA(50)        Neutral
#
#   hasFinancialReport.en      priceVsSMA100.en  \
# 0                   Yes  Price below SMA(100)
# 1                   Yes  Price below SMA(100)
# 2                   Yes  Price below SMA(100)
# 3                   Yes  Price below SMA(100)
#
#                              heatingUp.en
# 0                                     NaN
# 1                                     NaN
# 2  Overheated in previous trading session
# 3                                     NaN

# %% [markdown]
# ## Trend

# %%
trend_params = {
    "exchangeName": "HOSE,HNX",
    "marketCap": (1_000, 200_000),
    "epsGrowth5Year": (20, 100),  # Minimum 1-year EPS growth
#     "roe": (10, 100),  # Minimum Return on Equity (ROE)
#     'pe': (10,20),
#     'pb': (0,4),
    'priceNearRealtime': (10,100),
    'macdHistogram': 'macdHistLT0Increase',
    'strongBuyPercentage': (20,100),
    "avgTradingValue20Day": (100, 100_000),  # Minimum 20-day average trading value
    # 'uptrend': 'buy-signal',
}
df = filter_stocks(trend_params)
df.head()
# Out:
# ['DCM' 'DGC' 'DPM' 'HAH' 'HHV' 'IDC' 'MBB' 'MBS' 'STB' 'TCB']
#   ticker companyName  marketCap   roe  stockRating  businessOperation  \
# 0    DCM                  15511  16.8          4.7                4.3
# 1    DGC                  32585  30.2          4.6                4.9
# 2    DPM                  12366  13.0          4.8                4.2
# 3    HAH                   3260  20.6          4.7                4.3
# 4    HHV                   4776   4.7          3.4                3.7
#
#    businessModel  financialHealth  alpha  beta  activeBuyPercentage  \
# 0            4.0              5.0   -0.3   1.1                 40.4
# 1            4.2              4.8   -0.3   1.5                 55.5
# 2            3.8              5.0    0.2   1.0                 53.1
# 3            4.0              4.8   -0.1   0.6                 43.1
# 4            3.1              1.6   -0.2   1.7                 44.2
#
#    strongBuyPercentage  suddenlyHighVolumeMatching  forecastVolumeRatio    pe  \
# 0                 90.3                        12.3                  1.1   9.6
# 1                 28.7                         7.3                  0.7   9.5
# 2                 77.9                        16.4                  1.6   7.9
# 3                 95.9                         6.0                  0.9   6.6
# 4                 72.6                        11.2                  1.2  14.4
#
#     pb  evEbitda  dividendYield  revenueGrowth1Year  revenueGrowth5Year  \
# 0  1.6       5.2           12.4               61.35               22.61
# 1  2.7       9.3            6.9               51.24               87.36
# 2  1.1       6.3           19.4               45.68               18.43
# 3  1.3       4.7            0.0               63.94               32.74
# 4  0.6      19.2            0.0               12.53               37.06
#
#    epsGrowth1Year  epsGrowth5Year  grossMargin  netMargin  doe  \
# 0          136.69           46.58         5.89       2.45  0.0
# 1          133.03           81.18        34.09      30.91  0.1
# 2           78.53           51.62        12.69       1.99  0.1
# 3           84.49           20.18        23.22      15.51  0.4
# 4           -1.79           76.80        44.35      14.98  2.3
#
#    avgTradingValue5Day  avgTradingValue10Day  avgTradingValue20Day  \
# 0               119.37                161.91                188.27
# 1               231.11                252.58                315.57
# 2                84.35                101.67                138.24
# 3                81.60                 84.38                128.51
# 4                82.03                 85.69                132.80
#
#    relativeStrength3Day  relativeStrength1Month  relativeStrength3Month  \
# 0                    79                      20                      68
# 1                    79                      37                      93
# 2                    90                      13                      35
# 3                    89                       6                      60
# 4                    96                      25                      45
#
#    relativeStrength1Year  totalTradingValue  priceNearRealtime  rsi14  \
# 0                     44             125.17               29.3   41.6
# 1                     68             172.24               85.8   45.9
# 2                     21             128.67               31.6   39.0
# 3                     77              74.15               30.9   37.8
# 4                     89              96.23               14.5   45.5
#
#    foreignVolumePercent  tcRS  foreignBuySell20Session  \
# 0                 11.22    53                      383
# 1                 17.25    69                     4991
# 2                 10.70    40                    -5500
# 3                  4.84    58                      413
# 4                  6.66    64                     3317
#
#    numIncreaseContinuousDay  numDecreaseContinuousDay   eps  volumeVsVSma5  \
# 0                       NaN                       1.0  3050            1.2
# 1                       0.0                       0.0  9010            0.8
# 2                       3.0                       NaN  4017            2.1
# 3                       NaN                       1.0  4676            1.1
# 4                       3.0                       NaN  1004            1.4
#
#    volumeVsVSma10  volumeVsVSma20  volumeVsVSma50  priceGrowth1Week  \
# 0             0.8             0.8             0.8              2.81
# 1             0.7             0.6             0.5              0.94
# 2             1.5             1.1             1.0             -0.94
# 3             1.0             0.7             0.7             -2.83
# 4             1.2             0.8             0.7              3.57
#
#    priceGrowth1Month  prev1DayGrowthPercent  prev1MonthGrowthPercent  \
# 0             -16.76                  -1.84                   -16.76
# 1              -9.68                   0.00                    -9.68
# 2             -16.95                   2.43                   -16.95
# 3             -20.97                  -0.16                   -20.97
# 4             -13.69                   0.69                   -13.69
#
#    prev1YearGrowthPercent  prev5YearGrowthPercent  freeTransferRate  \
# 0                    4.82                  298.08                25
# 1                   24.98                  579.34                60
# 2                  -10.34                  129.45                45
# 3                   34.54                  320.50                70
# 4                   52.10                   63.05                80
#
#    netCashPerMarketCap  netCashPerTotalAssets  profitForTheLast4Quarters  \
# 0                 13.0                   13.7                     1614.7
# 1                 -2.8                   -6.2                     3421.6
# 2                  4.4                    3.8                     1572.2
# 3                -25.2                  -16.2                      493.4
# 4               -416.9                  -54.5                      330.6
#
#    lastQuarterRevenueGrowth  secondQuarterRevenueGrowth  \
# 0                      -9.0                       -19.4
# 1                     -33.3                       -39.7
# 2                     -17.2                       -26.1
# 3                     -12.5                       -34.2
# 4                      19.6                        26.5
#
#    lastQuarterProfitGrowth  secondQuarterProfitGrowth  percent1YearFromPeak  \
# 0                    -89.9                      -69.4                 -22.7
# 1                    -46.2                      -52.9                 -15.1
# 2                    -93.6                      -92.4                 -24.4
# 3                    -51.5                      -59.4                 -26.8
# 4                     38.0                       31.6                 -21.8
#
#    percentAwayFromHistoricalPeak  percent1YearFromBottom  \
# 0                          -29.7                    42.5
# 1                          -32.1                    90.2
# 2                          -45.6                    17.1
# 3                          -48.5                   106.9
# 4                          -42.2                   148.6
#
#    percentOffHistoricalBottom exchangeName.en              industryName.en  \
# 0                       544.3            HOSE                    Chemicals
# 1                      1607.6            HOSE                    Chemicals
# 2                       315.0            HOSE                    Chemicals
# 3                       499.7            HOSE  Industrial Goods & Services
# 4                       383.6            HOSE     Construction & Materials
#
#        priceVsSMA20.en foreignTransaction.en tcbsBuySellSignal.en  \
# 0  Price below SMA(20)            Buy < Sell                 Sell
# 1  Price below SMA(20)            Buy > Sell              Neutral
# 2  Price below SMA(20)            Buy < Sell                 Sell
# 3  Price below SMA(20)            Buy < Sell                 Sell
# 4  Price below SMA(20)            Buy < Sell              Neutral
#
#                   macdHistogram.en      priceVsSma50.en rsi14Status.en  \
# 0  MACD Histogram < 0 and increase  Price below SMA(50)        Neutral
# 1  MACD Histogram < 0 and increase  Price below SMA(50)        Neutral
# 2  MACD Histogram < 0 and increase  Price below SMA(50)        Neutral
# 3  MACD Histogram < 0 and increase  Price below SMA(50)        Neutral
# 4  MACD Histogram < 0 and increase  Price below SMA(50)        Neutral
#
#   hasFinancialReport.en      priceVsSMA100.en tcbsRecommend.en  \
# 0                   Yes  Price below SMA(100)              NaN
# 1                   Yes  Price below SMA(100)      Wait to buy
# 2                   Yes  Price below SMA(100)              NaN
# 3                   Yes  Price below SMA(100)      Wait to buy
# 4                   Yes  Price below SMA(100)              Buy
#
#   priceVsSma10.en heatingUp.en bollingBandSignal.en
# 0             NaN          NaN                  NaN
# 1             NaN          NaN                  NaN
# 2             NaN          NaN                  NaN
# 3             NaN          NaN                  NaN
# 4             NaN          NaN                  NaN
